# %% [markdown]
# # Gulf of Guinea (toy)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from subprocess import check_call

from datetime import datetime
from pathlib import Path

import cson_forge

# %% [markdown]
# ## Define the grid
#
# Specify the grid name and parameters defining its geometry and MPI domain decomposition.

# %%
model_name = "roms-marbl"
grid_name = "gulf-guinea-toy"

start_time = datetime(2012, 1, 1)
end_time = datetime(2012, 1, 2)

boundaries={
        "south": True,
        "east": True,
        "north": True,
        "west": True, 
    }

np_eta = 5 # number of partitions in eta (y) 
np_xi = 2 # number of partitions in xi (x) 

grid_kwargs = dict(
    nx=10,           # number of grid points in x-direction
    ny=10,           # number of grid points in y-direction
    size_x=4000,       # domain size in x-direction (km)
    size_y=2000,       # domain size in y-direction (km)
    center_lon=4.0,    # center longitude (E)
    center_lat=-1.0,    # center latitude (S)
    rot=0,            # no rotation
    N=5,             # number of vertical layers
)

ocn = cson_forge.OcnModel(
    model_name=model_name,
    grid_name=grid_name,
    grid_kwargs=grid_kwargs,
    boundaries=boundaries,    
    start_time=start_time,
    end_time=end_time,
    np_eta=np_eta,
    np_xi=np_xi,
)
ocn.grid.plot()

# %%
ocn.prepare_source_data(clobber=False)
# Out:
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-01: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_gulf-guinea-toy_20120101.nc
# ✔️  Using existing GLORYS_REGIONAL file for 2012-01-02: cmems_mod_glo_phy_my_0.083deg_P1D-m_REGIONAL_gulf-guinea-toy_20120102.nc
# ✔️  TPXO dataset verified at: /Users/mclong/cson-forge-data/source-data/TPXO/TPXO10.v2
# ✔️  Using existing BGC dataset: /Users/mclong/cson-forge-data/source-data/UNIFIED_BGC/BGCdataset.nc

# %%
inputs = ocn.generate_inputs(clobber=True)
# Out:
# ⚠️  Found existing ROMS input files in /Users/mclong/cson-forge-data/input-data/roms-marbl_gulf-guinea-toy
#     Not overwriting because clobber=False.
#
# Exiting without changes.

# %% [markdown]
# ### Quick look at some forcing

# %%
inputs["initial_conditions"].plot("DIC", s=-1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 inputs["initial_conditions"].plot("DIC", s=-1)
#
# KeyError: 'initial_conditions'

# %%
inputs["surface_forcing"].plot("uwnd", time=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 inputs["surface_forcing"].plot("uwnd", time=0)
#
# KeyError: 'surface_forcing'

# %% [markdown]
# ## Build the model
#
# Apply templating to source code and input files, then build the model

# %%
parameters = {
    "param.opt": dict(NP_XI=np_xi, NP_ETA=np_eta, NX=ocn.grid.nx, NY=ocn.grid.ny, NK=ocn.grid.N),
    "river_frc.opt": dict(nriv=23), #inputs["rivers"].ds.sizes["nriver"]),
}

ocn.build(parameters, clean=True)
# Out:
# Build token: 20251214T214537Z-24a100f0
# Building roms-marbl for grid: gulf-guinea-toy
# roms-marbl opt_base_dir : /Users/mclong/codes/cson-forge/cson_forge/model-configs/opt_base/opt_base_roms-marbl-cson-default
# ROMS opt_dir      : /Users/mclong/codes/cson-forge/cson_forge/builds/roms-marbl_gulf-guinea-toy/opt
# ROMS build_dir    : /Users/mclong/codes/cson-forge/cson_forge/builds/roms-marbl_gulf-guinea-toy/bld
# Input data path   : /Users/mclong/cson-forge-data/input-data/roms-marbl_gulf-guinea-toy
# ROMS_ROOT         : /Users/mclong/cson-forge-data/codes/ucla-roms
# MARBL_ROOT        : /Users/mclong/cson-forge-data/codes/MARBL
# Logs              : /Users/mclong/codes/cson-forge/cson_forge/builds/roms-marbl_gulf-guinea-toy/logs
# Build environment : conda
# ROMS repo already present at /Users/mclong/cson-forge-data/codes/ucla-roms
# MARBL repo already present at /Users/mclong/cson-forge-data/codes/MARBL
# Checking out MARBL marbl0.45.0
# Conda env 'roms_env' already exists.
# Using compiler kind: gnu
# Found 2 existing build(s) in /Users/mclong/codes/cson-forge/cson_forge/builds.yml.
# # packages in environment at /Users/mclong/miniconda3/envs/roms_env:
# #
# # Name                         Version          Build                  Channel
# blosc                          1.21.6           h7dd00d9_1             conda-forge
# bzip2                          1.0.8            hd037594_8             conda-forge
# c-ares                         1.34.5           h5505292_0             conda-forge
# c-compiler                     1.11.0           h61f9b84_0             conda-forge
# ca-certificates                2025.10.5        hbd8a1cb_0             conda-forge
# cctools                        1024.3           hd01ab73_9             conda-forge
# cctools_osx-arm64              1024.3           llvm19_1_h8c76c84_9    conda-forge
# clang                          19.1.7           default_hf9bcbb7_5     conda-forge
# clang-19                       19.1.7           default_h73dfc95_5     conda-forge
# clang_impl_osx-arm64           19.1.7           h76e6a08_25            conda-forge
# clang_osx-arm64                19.1.7           h07b0088_25            conda-forge
# clangxx                        19.1.7           default_h36137df_5     conda-forge
# clangxx_impl_osx-arm64         19.1.7           h276745f_25            conda-forge
# clangxx_osx-arm64              19.1.7           h07b0088_25            conda-forge
# compiler-rt                    19.1.7           h855ad52_1             conda-forge
# compiler-rt_osx-arm64          19.1.7           he32a8d3_1             conda-forge
# compilers                      1.11.0           hce30654_0             conda-forge
# cxx-compiler                   1.11.0           h88570a1_0             conda-forge
# fortran-compiler               1.11.0           h81a4f41_0             conda-forge
# gfortran                       14.3.0           h3ef1dbf_0             conda-forge
# gfortran_impl_osx-arm64        14.3.0           h6d03799_1             conda-forge
# gfortran_osx-arm64             14.3.0           h3c33bd0_0             conda-forge
# gmp                            6.3.0            h7bae524_2             conda-forge
# hdf4                           4.2.15           h2ee6834_7             conda-forge
# hdf5                           1.14.6           nompi_he65715a_103     conda-forge
# icu                            75.1             hfee45f7_0             conda-forge
# isl                            0.26             imath32_h347afa1_101   conda-forge
# krb5                           1.21.3           h237132a_0             conda-forge
# ld64                           955.13           he86490a_9             conda-forge
# ld64_osx-arm64                 955.13           llvm19_1_h6922315_9    conda-forge
# libaec                         1.1.4            h51d1e36_0             conda-forge
# libblas                        3.9.0            38_h51639a9_openblas   conda-forge
# libcblas                       3.9.0            38_hb0561ab_openblas   conda-forge
# libclang-cpp19.1               19.1.7           default_h73dfc95_5     conda-forge
# libcurl                        8.17.0           hdece5d2_0             conda-forge
# libcxx                         21.1.5           hf598326_0             conda-forge
# libcxx-devel                   19.1.7           h6dc3340_1             conda-forge
# libedit                        3.1.20250104     pl5321hafb1f1b_0       conda-forge
# libev                          4.33             h93a5062_2             conda-forge
# libexpat                       2.7.1            hec049ff_0             conda-forge
# libfabric                      2.3.1            hce30654_1             conda-forge
# libfabric1                     2.3.1            hc919400_1             conda-forge
# libffi                         3.5.2            he5f378a_0             conda-forge
# libgfortran                    15.2.0           hfcf01ff_1             conda-forge
# libgfortran-devel_osx-arm64    14.3.0           hc965647_1             conda-forge
# libgfortran5                   15.2.0           h742603c_1             conda-forge
# libhwloc                       2.12.1           default_h48b22c3_1002  conda-forge
# libiconv                       1.18             h23cfdf5_2             conda-forge
# libjpeg-turbo                  3.1.2            hc919400_0             conda-forge
# liblapack                      3.9.0            38_hd9741b5_openblas   conda-forge
# libllvm19                      19.1.7           h8e0c9ce_2             conda-forge
# liblzma                        5.8.1            h39f12f2_2             conda-forge
# libnetcdf                      4.9.3            nompi_h80c4520_103     conda-forge
# libnghttp2                     1.67.0           hc438710_0             conda-forge
# libopenblas                    0.3.30           openmp_ha158390_3      conda-forge
# libsqlite                      3.51.0           h8adb53f_0             conda-forge
# libssh2                        1.11.1           h1590b86_0             conda-forge
# libxml2                        2.15.1           h9329255_0             conda-forge
# libxml2-16                     2.15.1           h0ff4647_0             conda-forge
# libzip                         1.11.2           h1336266_0             conda-forge
# libzlib                        1.3.1            h8359307_2             conda-forge
# llvm-openmp                    21.1.5           h4a912ad_0             conda-forge
# llvm-tools                     19.1.7           h855ad52_2             conda-forge
# llvm-tools-19                  19.1.7           h91fd4e7_2             conda-forge
# lz4-c                          1.10.0           h286801f_1             conda-forge
# mpc                            1.3.1            h8f1351a_1             conda-forge
# mpfr                           4.2.1            hb693164_3             conda-forge
# mpi                            1.0.1            mpich                  conda-forge
# mpich                          4.3.2            hf5485c1_100           conda-forge
# ncurses                        6.5              h5e97a16_3             conda-forge
# netcdf-fortran                 4.6.2            nompi_h799d18b_102     conda-forge
# numpy                          2.2.6            py310h4d83441_0        conda-forge
# openssl                        3.5.4            h5503f6c_0             conda-forge
# pip                            25.3             pyh8b19718_0           conda-forge
# python                         3.10.19          hcd7f573_2_cpython     conda-forge
# python_abi                     3.10             8_cp310                conda-forge
# readline                       8.2              h1d1bf99_2             conda-forge
# setuptools                     80.9.0           pyhff2d567_0           conda-forge
# sigtool                        0.1.3            h44b9a77_0             conda-forge
# snappy                         1.2.2            hd121638_0             conda-forge
# tapi                           1300.6.5         h03f4b80_0             conda-forge
# tk                             8.6.13           h892fb3f_2             conda-forge
# tzdata                         2025b            h78e105d_0             conda-forge
# wheel                          0.45.1           pyhd8ed1ab_1           conda-forge
# zlib                           1.3.1            h8359307_2             conda-forge
# zstd                           1.5.7            h6491c7d_2             conda-forge
# [Clean] MARBL/src ...
# rm -f /Users/mclong/cson-forge-data/codes/MARBL/tests/obj/*/shared_deps.d /Users/mclong/cson-forge-data/codes/MARBL/lib/libmarbl*.a
# find /Users/mclong/cson-forge-data/codes/MARBL/tests/obj -maxdepth 2 -name marbl_*.o | xargs rm -f
# find /Users/mclong/cson-forge-data/codes/MARBL/tests/obj -maxdepth 2 -name marbl_*.mod | xargs rm -f
# find /Users/mclong/cson-forge-data/codes/MARBL/include -maxdepth 2 -name marbl_*.mod | xargs rm -f
#
# [Build MARBL (compiler: gnu)] starting...

# %%
ocn.run(case="test.001")
# Out:
# Copying settings input files from /Users/mclong/codes/cson-forge/workflows/builds/roms-marbl_gulf-guinea-toy/opt to /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_gulf-guinea-toy/test.001:
#   roms.in -> /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_gulf-guinea-toy/test.001/roms.in
#   marbl_in -> /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_gulf-guinea-toy/test.001/marbl_in
#   marbl_tracer_output_list -> /Users/mclong/cson-forge-data/cson-forge-run/roms-marbl_gulf-guinea-toy/test.001/marbl_tracer_output_list
# Rendering master settings file: roms.in
# ---------------------------------------------------------------------------
# UndefinedError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ocn.run(case="test.001")
#
# File ~/codes/cson-forge/workflows/cson_forge.py:1919, in OcnModel.run(self, case, cluster_type, account, queue, wallclock_time)
#    1913 if self.executable is None:
#    1914     raise RuntimeError(
#    1915         "You must call OcnModel.build() "
#    1916         "before running the model."
#    1917     )
# -> 1919 run(
#    1920     model_spec=self.spec,
#    1921     grid_name=self.grid_name,
#    1922     case=case,
#    1923     input_data_path=self.inputs.input_data_dir,
#    1924     executable_path=self.executable,
#    1925     run_command=self._run_command,
#    1926     inputs=self.inputs.inputs,
#    1927     cluster_type=cluster_type,
#    1928     account=account,
#    1929     queue=queue,
#    1930     wallclock_time=wallclock_time,
#    1931 )
#
# File ~/codes/cson-forge/workflows/cson_forge.py:1588, in run(model_spec, grid_name, case, input_data_path, executable_path, run_command, inputs, cluster_type, account, queue, wallclock_time, log_func)
#    1582 env = Environment(
#    1583     loader=FileSystemLoader(str(opt_dir)),
#    1584     undefined=StrictUndefined,
#    1585     autoescape=False,
#    1586 )
#    1587 template = env.get_template(model_spec.master_settings_file)
# -> 1588 rendered = template.render(**context)
#    1590 # Write to run directory
#    1591 master_settings_dst.write_text(rendered)
#
# File ~/miniconda3/envs/cson-forge/lib/python3.13/site-packages/jinja2/environment.py:1295, in Template.render(self, *args, **kwargs)
#    1293     return self.environment.concat(self.root_render_func(ctx))  # type: ignore
#    1294 except Exception:
# -> 1295     self.environment.handle_exception()
#
# File ~/miniconda3/envs/cson-forge/lib/python3.13/site-packages/jinja2/environment.py:942, in Environment.handle_exception(self, source)
#     937 """Exception handling helper.  This is used internally to either raise
#     938 rewritten exceptions or return a rendered traceback for the template.
#     939 """
#     940 from .debug import rewrite_traceback_stack
# --> 942 raise rewrite_traceback_stack(source=source)
#
# File ~/codes/cson-forge/workflows/builds/roms-marbl_gulf-guinea-toy/opt/roms.in:11, in top-level template code()
#       9
#      10 grid:  filename
# ---> 11       {{ GRID_PATH }}
#      12
#      13 forcing: filename
#
# UndefinedError: 'GRID_PATH' is undefined
