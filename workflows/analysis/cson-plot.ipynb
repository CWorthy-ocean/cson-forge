# %% [markdown]
# # Plot CSON

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
from glob import glob
from pathlib import Path

import matplotlib.pyplot as plt
import matplotlib.colors as colors

import cartopy
import cartopy.crs as ccrs

import cmocean

import roms_tools as rt
from cson_forge import catalog

# %%
grids = {}
for _, row in df.iterrows():
    name = row["grid_name"]
    grid_yaml_path = row["grid_yaml_path"]
    grids[name] = rt.Grid.from_yaml(grid_yaml_path)
# Out:
# 2025-12-14 22:32:26 - WARNING - Current roms-tools version (3.3.0) does not match the version in the YAML header (3.2.0).
# 2025-12-14 22:32:29 - WARNING - Current roms-tools version (3.3.0) does not match the version in the YAML header (3.2.0).
# 2025-12-14 22:32:29 - WARNING - Current roms-tools version (3.3.0) does not match the version in the YAML header (3.2.0).
# 2025-12-14 22:32:32 - WARNING - Current roms-tools version (3.3.0) does not match the version in the YAML header (3.2.0).

# %%
prj = ccrs.Robinson(central_longitude=305.0)

fig, ax = plt.subplots(
    figsize=(12, 12),
    facecolor='k',
    subplot_kw=dict(projection=prj),
)

ocean = ax.add_feature(
    cartopy.feature.NaturalEarthFeature(
        'physical','ocean','110m',
        edgecolor='face',
        facecolor='#749EB0',
        zorder=-9999,
    )
)

land = ax.add_feature(
     cartopy.feature.NaturalEarthFeature(
         'physical','land','110m',
         edgecolor='face',
         facecolor='#355560'
     )
 )

ax.coastlines()

ax.spines['geo'].set_visible(True)
ax.spines['geo'].set_linewidth(2)
ax.spines['geo'].set_edgecolor('black')

for g in grids.values():
    ax.pcolormesh(
        g.ds.lon_rho, g.ds.lat_rho, g.ds.h, 
        #edgecolors='k', linewidth=0.25,
        transform=ccrs.PlateCarree(),
        cmap=cmocean.cm.deep,
    )
    
ax.set_global() # For a global map

fig_size = (16, 9)
fig.set_size_inches(fig_size)
fig.tight_layout()

fig.savefig('assets/cson.png', dpi=300, transparent=True)

# %%
for name, g in grids.items():
    rt.plot.plot(g.ds.h, g.ds) # , ax=ax) passing an axis is broken https://github.com/CWorthy-ocean/roms-tools/issues/489
    plt.gca().set_title(name)
