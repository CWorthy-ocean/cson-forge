# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import source_data

# %%
source_data = source_data.SourceData(
    datasets=["SRTM15"],
    clobber=False,
).prepare_all()
# Out:
# ✔️  Using existing SRTM15+ dataset: /Users/mclong/cson-forge-data/source_data/SRTM15_V2.7.nc
