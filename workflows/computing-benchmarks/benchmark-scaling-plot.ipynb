# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path
from glob import glob
from subprocess import check_call, CalledProcessError

import numpy as np
import yaml

import matplotlib.pyplot as plt

import cson_forge
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /home/x-mlong/.local/share/mamba/envs/cson-forge-v0/share/proj failed

# %% [markdown]
# Query the blueprint catalog to find the run blueprint matching the specified model and grid. This provides the path to the simulation output directory.

# %% [markdown]
# Find all model output files matching the pattern. These files contain the time-series data for the variable of interest.

# %%
domains_file = "domains-bm-scaling.yml"

# %%
# Read domains file and extract domain keys
# Resolve domains file path (relative to notebook directory)
domains_path = Path(domains_file)
if not domains_path.is_absolute():
    domains_path = Path.cwd() / domains_path

# Load domains YAML file
with open(domains_path, 'r') as f:
    domains_data = yaml.safe_load(f) or {}

# Extract domain keys (main keys in the YAML file)
domain_keys = list(domains_data.keys())

print(f"Loaded {len(domain_keys)} domain(s) from {domains_path}")
print(f"Domain keys: {domain_keys}")
# Out:
# Loaded 5 domain(s) from /home/x-mlong/codes/cson-forge/workflows/computing-benchmarks/domains-bm-scaling.yml
# Domain keys: ['ccs-12km_20procs', 'ccs-12km_70procs', 'ccs-12km_280procs', 'ccs-12km_352procs', 'ccs-12km_1232procs']

# %% [markdown]
# Load the model grid from the blueprint's grid YAML file. The grid provides coordinate information (lon_rho, lat_rho) and masking for proper visualization.

# %%
df = cson_forge.catalog.blueprint.load(stage="run")
# Blueprint names are {model_name}_{grid_name}_{n_procs}procs
# Domain keys are {grid_name}_{n_procs}procs
# So we need to check if blueprint_name ends with any domain_key

#df = df.loc[df.blueprint_name.str.endswith(tuple(domain_keys))]
df = df[df["blueprint_name"].str.contains(r"_(010|020|030|040)\b", na=False)]

if df.empty:
    raise ValueError(
        f"No blueprints found: blueprint_name='{domain_keys}' "
        f"at stage='run'"
    )

df
# Out:
# /tmp/ipykernel_4094093/2209734307.py:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df = df[df["blueprint_name"].str.contains(r"_(010|020|030|040)\b", na=False)]
#                                  model_name grid_name  \
# 6   cson_roms-marbl_v0.1_ccs-12km_1232procs       010
# 7   cson_roms-marbl_v0.1_ccs-12km_1232procs       020
# 8   cson_roms-marbl_v0.1_ccs-12km_1232procs       030
# 9   cson_roms-marbl_v0.1_ccs-12km_1232procs       040
# 12    cson_roms-marbl_v0.1_ccs-12km_20procs       010
# 13    cson_roms-marbl_v0.1_ccs-12km_20procs       020
# 14    cson_roms-marbl_v0.1_ccs-12km_20procs       030
# 15    cson_roms-marbl_v0.1_ccs-12km_20procs       040
# 18   cson_roms-marbl_v0.1_ccs-12km_280procs       010
# 19   cson_roms-marbl_v0.1_ccs-12km_280procs       020
# 20   cson_roms-marbl_v0.1_ccs-12km_280procs       030
# 21   cson_roms-marbl_v0.1_ccs-12km_280procs       040
# 24   cson_roms-marbl_v0.1_ccs-12km_352procs       010
# 25   cson_roms-marbl_v0.1_ccs-12km_352procs       020
# 26   cson_roms-marbl_v0.1_ccs-12km_352procs       030
# 27   cson_roms-marbl_v0.1_ccs-12km_352procs       040
# 30    cson_roms-marbl_v0.1_ccs-12km_70procs       010
# 31    cson_roms-marbl_v0.1_ccs-12km_70procs       020
# 32    cson_roms-marbl_v0.1_ccs-12km_70procs       030
# 33    cson_roms-marbl_v0.1_ccs-12km_70procs       040
#
#                                  blueprint_name                description  \
# 6   cson_roms-marbl_v0.1_ccs-12km_1232procs_010  California Current System
# 7   cson_roms-marbl_v0.1_ccs-12km_1232procs_020  California Current System
# 8   cson_roms-marbl_v0.1_ccs-12km_1232procs_030  California Current System
# 9   cson_roms-marbl_v0.1_ccs-12km_1232procs_040  California Current System
# 12    cson_roms-marbl_v0.1_ccs-12km_20procs_010  California Current System
# 13    cson_roms-marbl_v0.1_ccs-12km_20procs_020  California Current System
# 14    cson_roms-marbl_v0.1_ccs-12km_20procs_030  California Current System
# 15    cson_roms-marbl_v0.1_ccs-12km_20procs_040  California Current System
# 18   cson_roms-marbl_v0.1_ccs-12km_280procs_010  California Current System
# 19   cson_roms-marbl_v0.1_ccs-12km_280procs_020  California Current System
# 20   cson_roms-marbl_v0.1_ccs-12km_280procs_030  California Current System
# 21   cson_roms-marbl_v0.1_ccs-12km_280procs_040  California Current System
# 24   cson_roms-marbl_v0.1_ccs-12km_352procs_010  California Current System
# 25   cson_roms-marbl_v0.1_ccs-12km_352procs_020  California Current System
# 26   cson_roms-marbl_v0.1_ccs-12km_352procs_030  California Current System
# 27   cson_roms-marbl_v0.1_ccs-12km_352procs_040  California Current System
# 30    cson_roms-marbl_v0.1_ccs-12km_70procs_010  California Current System
# 31    cson_roms-marbl_v0.1_ccs-12km_70procs_020  California Current System
# 32    cson_roms-marbl_v0.1_ccs-12km_70procs_030  California Current System
# 33    cson_roms-marbl_v0.1_ccs-12km_70procs_040  California Current System
#
#              start_time             end_time  \
# 6   2024-01-01T00:00:00  2024-01-10T00:00:00
# 7   2024-01-01T00:00:00  2024-01-10T00:00:00
# 8   2024-01-01T00:00:00  2024-01-10T00:00:00
# 9   2024-01-01T00:00:00  2024-01-10T00:00:00
# 12  2024-01-01T00:00:00  2024-01-10T00:00:00
# 13  2024-01-01T00:00:00  2024-01-10T00:00:00
# 14  2024-01-01T00:00:00  2024-01-10T00:00:00
# 15  2024-01-01T00:00:00  2024-01-10T00:00:00
# 18  2024-01-01T00:00:00  2024-01-10T00:00:00
# 19  2024-01-01T00:00:00  2024-01-10T00:00:00
# 20  2024-01-01T00:00:00  2024-01-10T00:00:00
# 21  2024-01-01T00:00:00  2024-01-10T00:00:00
# 24  2024-01-01T00:00:00  2024-01-10T00:00:00
# 25  2024-01-01T00:00:00  2024-01-10T00:00:00
# 26  2024-01-01T00:00:00  2024-01-10T00:00:00
# 27  2024-01-01T00:00:00  2024-01-10T00:00:00
# 30  2024-01-01T00:00:00  2024-01-10T00:00:00
# 31  2024-01-01T00:00:00  2024-01-10T00:00:00
# 32  2024-01-01T00:00:00  2024-01-10T00:00:00
# 33  2024-01-01T00:00:00  2024-01-10T00:00:00
#
#                                        blueprint_path  \
# 6   /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 7   /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 8   /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 9   /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 12  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 13  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 14  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 15  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 18  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 19  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 20  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 21  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 24  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 25  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 26  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 27  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 30  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 31  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 32  /home/x-mlong/codes/cson-forge/cson_forge/blue...
# 33  /home/x-mlong/codes/cson-forge/cson_forge/blue...
#
#                                        grid_yaml_path stage
# 6   /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 7   /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 8   /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 9   /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 12  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 13  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 14  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 15  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 18  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 19  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 20  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 21  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 24  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 25  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 26  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 27  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 30  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 31  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 32  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run
# 33  /home/x-mlong/codes/cson-forge/cson_forge/blue...   run

# %%
job_ids = {}
rows = []
for i in range(len(df)):
    key = df.blueprint_name.iloc[i]
    blueprint_path = df.blueprint_path.iloc[i] 

    # configuration info
    grid_yaml = df.grid_yaml_path.iloc[i]  
    grid_obj = cson_forge.parsers.load_roms_tools_object(grid_yaml)
   
    dof = grid_obj.ds.sizes["eta_rho"] * grid_obj.ds.sizes["xi_rho"] * grid_obj.ds.sizes["s_rho"]

    settings_path = blueprint_path.parent / (blueprint_path.stem.replace("B_", "settings_B_") + ".yml")
    with open(settings_path, "r") as file:
        data = yaml.safe_load(file)
    nsteps = data["run_time"]["roms.in"]["time_stepping"]["ntimes"]
    dt = data["run_time"]["roms.in"]["time_stepping"]["dt"]    

    # log file and SLURM info
    casename = blueprint_path.stem.replace("B_", "").replace("_run", "") # get less janky
    simulation_dir = Path(cson_forge.config.paths.scratch / casename)    
    log_file = simulation_dir / "logs" / (f"{casename}".replace("_run", "").replace(".", "-") + ".out")
    if not log_file.exists():
        print(f"Log file {log_file} does not exist")
        continue
    
    job_id = cson_forge.parsers.parse_slurm_job_id(log_file)
    info = cson_forge.parsers.sacct_summary(job_id)

    # store data
    row = {
        "model": key,
        "ntasks": info["ntasks"],
        "elapsed_time": info["elapsed_time"],
        "dof": dof,
        "nsteps": nsteps,
        "dt": dt,
        "performance_number": info["ntasks"] * info["elapsed_time"] / (dof * nsteps),
    }
    rows.append(row)

df_info = pd.DataFrame(rows)
df_info
# Out:
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
# [WARNING] Current roms-tools version (3.4.0) does not match the version in the YAML header (3.3.0).
#                                           model  ntasks  elapsed_time  \
# 0   cson_roms-marbl_v0.1_ccs-12km_1232procs_010    1232          3011
# 1   cson_roms-marbl_v0.1_ccs-12km_1232procs_020    1232          2999
# 2   cson_roms-marbl_v0.1_ccs-12km_1232procs_030    1232          3090
# 3   cson_roms-marbl_v0.1_ccs-12km_1232procs_040    1232          2968
# 4     cson_roms-marbl_v0.1_ccs-12km_20procs_010      20         21608
# 5     cson_roms-marbl_v0.1_ccs-12km_20procs_020      20         21611
# 6     cson_roms-marbl_v0.1_ccs-12km_20procs_030      20         21626
# 7     cson_roms-marbl_v0.1_ccs-12km_20procs_040      20         21600
# 8    cson_roms-marbl_v0.1_ccs-12km_280procs_010     280          5517
# 9    cson_roms-marbl_v0.1_ccs-12km_280procs_020     280          5524
# 10   cson_roms-marbl_v0.1_ccs-12km_280procs_030     280          5529
# 11   cson_roms-marbl_v0.1_ccs-12km_280procs_040     280          5563
# 12   cson_roms-marbl_v0.1_ccs-12km_352procs_010     352          5267
# 13   cson_roms-marbl_v0.1_ccs-12km_352procs_020     352          5239
# 14   cson_roms-marbl_v0.1_ccs-12km_352procs_030     352          5275
# 15   cson_roms-marbl_v0.1_ccs-12km_352procs_040     352          5267
# 16    cson_roms-marbl_v0.1_ccs-12km_70procs_010      70         18554
# 17    cson_roms-marbl_v0.1_ccs-12km_70procs_020      70         18573
# 18    cson_roms-marbl_v0.1_ccs-12km_70procs_030      70         18484
# 19    cson_roms-marbl_v0.1_ccs-12km_70procs_040      70         18475
#
#         dof  nsteps  dt  performance_number
# 0   5993520   24300  32            0.000025
# 1   5993520   24300  32            0.000025
# 2   5993520   24300  32            0.000026
# 3   5993520   24300  32            0.000025
# 4   5993520   24300  32            0.000003
# 5   5993520   24300  32            0.000003
# 6   5993520   24300  32            0.000003
# 7   5993520   24300  32            0.000003
# 8   5993520   24300  32            0.000011
# 9   5993520   24300  32            0.000011
# 10  5993520   24300  32            0.000011
# 11  5993520   24300  32            0.000011
# 12  5993520   24300  32            0.000013
# 13  5993520   24300  32            0.000013
# 14  5993520   24300  32            0.000013
# 15  5993520   24300  32            0.000013
# 16  5993520   24300  32            0.000009
# 17  5993520   24300  32            0.000009
# 18  5993520   24300  32            0.000009
# 19  5993520   24300  32            0.000009

# %%
print(f"P = {df_info.performance_number.mean():0.3e} ± {df_info.performance_number.std():0.3e}")
# Out:
# P = 1.215e-05 ± 7.628e-06

# %%
summary = (
    df_info
    .groupby("ntasks", as_index=False)
    .agg(
        mean_time=("elapsed_time", "mean"),
        std_time=("elapsed_time", "std"),
        n_runs=("elapsed_time", "count"),
    )
)
summary = summary.sort_values("ntasks")
summary
# Out:
#    ntasks  mean_time   std_time  n_runs
# 0      20   21611.25  10.067628       8
# 1      70   18521.50  45.597619       8
# 2     280    5533.25  18.919000       8
# 3     352    5262.00  14.618970       8
# 4    1232    3017.00  48.077319       8

# %%
plt.figure(figsize=(6, 4))

ntasks = summary.ntasks.to_numpy()
time_mean = summary.mean_time.to_numpy()
time_std = summary.std_time.to_numpy()

plt.errorbar(
    ntasks,
    time_mean,
    yerr=time_std,
    fmt='o',
    capsize=1,
    label="ROMS–MARBL"
)


# Ideal strong-scaling line (relative to smallest ntasks)
ntasks = summary.ntasks.to_numpy()
t = summary.mean_time.to_numpy()
ideal = t[0] * ntasks[0] / ntasks

plt.plot(ntasks, ideal, linestyle='-', color="gray", alpha=0.8, label="Ideal scaling: T ∝ N$^{-1}$")

# ---- Best-fit power-law line ----
logN = np.log10(ntasks)
logT = np.log10(time_mean)

slope, intercept = np.polyfit(logN, logT, 1)
fit_time = 10 ** (intercept + slope * logN)

plt.plot(
    ntasks,
    fit_time,
    linestyle='-',
    color='tab:red',
    label=f"Best fit: T ∝ N$^{{{slope:.2f}}}$"
)

plt.xscale("log")
plt.yscale("log")
plt.xlabel("Number of MPI tasks")
plt.ylabel("Wall-clock time (s)")
plt.title("ROMS–MARBL Strong Scaling (12 km CCS)")
plt.legend()
plt.grid(True, which="both", linestyle=":")

plt.tight_layout()
plt.show()

# %% [markdown]
# Old data from Pierre:

# %%
ntasks = np.array([128, 256, 384, 640, 896, 1280])
time_mean = np.array([707.9, 307.7, 201.0, 127.2, 96.1, 70.1])

plt.plot(ntasks, time_mean, "*", color="tab:blue", label="Actual")
ideal = time_mean[0] * ntasks[0] / ntasks

plt.plot(ntasks, ideal, linestyle='-', color="gray", alpha=0.8, label="Ideal scaling: T ∝ N$^{-1}$")


plt.xscale("log")
plt.yscale("log")
plt.xlabel("Number of MPI tasks")
plt.ylabel("Wall-clock time (s)")
plt.title("ROMS–MARBL Strong Scaling (12 km CCS)")
plt.legend()
plt.grid(True, which="both", linestyle=":")

plt.tight_layout()
plt.show()

# %%
t0
# Out:
# np.float64(21611.25)
